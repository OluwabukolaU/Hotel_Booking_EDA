# %%
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# C:\Users\adsa\AppData\Local\Temp\ipykernel_16988\2554512389.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\adsa\Downloads\hotel_booking\hotel_bookings.csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
#UNDERSTANDING THE DATA

# %%
df.shape
# Out:
# (119390, 32)

# %%
pd.set_option('display.max_columns',32)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %%
df['hotel'].value_counts()  #this dataset is not balanced, it is inbalanced dataset
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64

# %%
df['meal'].value_counts()
# Out:
# meal
# BB           92310
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: count, dtype: int64

# %%
df['distribution_channel'].value_counts()
# Out:
# distribution_channel
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: count, dtype: int64

# %%
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %%
df['deposit_type'].value_counts()
# Out:
# deposit_type
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: count, dtype: int64

# %%
df['customer_type'].value_counts()
# Out:
# customer_type
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: count, dtype: int64

# %%
df['total_of_special_requests'].value_counts()
# Out:
# total_of_special_requests
# 0    70318
# 1    33226
# 2    12969
# 3     2497
# 4      340
# 5       40
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x="hotel")
# Out:
# <Axes: xlabel='hotel', ylabel='count'>

# %%
sns.countplot(data=df,x='is_canceled',hue='is_repeated_guest')
# Out:
# <Axes: xlabel='is_canceled', ylabel='count'>

# %%
sns.countplot(data=df, x='hotel', hue='is_canceled')
# Out:
# <Axes: xlabel='hotel', ylabel='count'>

# %%
#DATA PREPARATION

# %%
#MISSING VALUE

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#replacing null value with zero
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
#Meal contains "undefined",which is equal to SC
df['meal'] = df['meal'].replace('Undefined', 'SC')

# %%
df['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC'], dtype=object)

# %%
Subset=df[(df['children']==0) & (df['adults']==0) & (df['babies']==0)]

# %%
Subset[['adults','babies','children']]
# Out:
#         adults  babies  children
# 2224         0       0       0.0
# 2409         0       0       0.0
# 3181         0       0       0.0
# 3684         0       0       0.0
# 3708         0       0       0.0
# ...        ...     ...       ...
# 115029       0       0       0.0
# 115091       0       0       0.0
# 116251       0       0       0.0
# 116534       0       0       0.0
# 117087       0       0       0.0
#
# [180 rows x 3 columns]

# %%
type(Subset)
# Out:
# pandas.core.frame.DataFrame

# %%
Delete=(df['children']==0) & (df['adults']==0) & (df['babies']==0)

# %%
type(Delete)
# Out:
# pandas.core.series.Series

# %%
Delete
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Length: 119390, dtype: bool

# %%
data=df[~Delete]

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
Subset=data[(data['children']==0) & (data['adults']==0) & (data['babies']==0)]

# %%
Subset
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date]
# Index: []

# %%
data.shape
# Out:
# (119210, 32)

# %%
119390-119210
# Out:
# 180

# %% [markdown]
# WHERE DO THE GUEST COME FROME?

# %%
guest_country=data[data['is_canceled']==0]['country'].value_counts().reset_index()
guest_country.columns=['country','Number of guests']

# %%
guest_country
# Out:
#     country  Number of guests
# 0       PRT             20977
# 1       GBR              9668
# 2       FRA              8468
# 3       ESP              6383
# 4       DEU              6067
# ..      ...               ...
# 161     BHR                 1
# 162     DJI                 1
# 163     MLI                 1
# 164     NPL                 1
# 165     FRO                 1
#
# [166 rows x 2 columns]

# %%
# !pip install plotly
import plotly.io as pio
import plotly.offline as pyo
import plotly.graph_objs as go
import plotly.express as px
pio.renderers.default = 'notebook'
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
print(guest_country.head())
print(guest_country.shape)
# Out:
#   country  Number of guests
# 0     PRT             20977
# 1     GBR              9668
# 2     FRA              8468
# 3     ESP              6383
# 4     DEU              6067
# (166, 2)

# %% [raw]
# total_guests = guest_country["Number of guests"].sum()
# print(total_guests)

# %%
guest_country['Guests in %'] = round(guest_country["Number of guests"] / total_guests * 100, 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 guest_country['Guests in %'] = round(guest_country["Number of guests"] / total_guests * 100, 2)
#
# NameError: name 'total_guests' is not defined

# %%
print(guest_country.columns)

# %%
#This code creates a bronze-colored bar chart showing the number
#of guests from different countries, with countries on the x-axis and the number of guests on the y-axis.
trace= go.Bar(
    x=guest_country["country"],
    y=guest_country["Number of guests"],
    marker=dict(color='#CD7F32')
)
data1 = [trace]
layout = go.Layout(
    title='Guests by Country'
)
fig= go.Figure(data=data1, layout=layout)
pyo.plot(fig)

# %% [markdown]
# map_guest = px.choropleth(guest_country,
#                           locations='country',
#                           color='Number of guests',
#                           hover_name='country',
#                           title='Home country of guests')
# map_guest.show()

# %% [markdown]
# # Price Variation/person over the year,  I will use the avaerage values over the year

# %% [markdown]
# # How does  the price per night vary over the year?

# %% [markdown]
# # STEP 1 Creating seperate DF for resort and city hotel

# %%
resort = data[(data['hotel'] == 'Resort Hotel') & (data['is_canceled'] ==0)]
city = data[(data['hotel'] == 'City Hotel') & (data['is_canceled'] ==0)]
resort
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 40055  Resort Hotel            0        212               2017
# 40056  Resort Hotel            0        169               2017
# 40057  Resort Hotel            0        204               2017
# 40058  Resort Hotel            0        211               2017
# 40059  Resort Hotel            0        161               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
resort_hotel =resort.groupby(['arrival_date_month'])['adr'].mean().reset_index()
resort_hotel
# Out:
#    arrival_date_month         adr
# 0               April   75.867816
# 1              August  181.205892
# 2            December   68.410104
# 3            February   54.147478
# 4             January   48.761125
# 5                July  150.122528
# 6                June  107.974850
# 7               March   57.056838
# 8                 May   76.657558
# 9            November   48.706289
# 10            October   61.775449
# 11          September   96.416860

# %%
city_hotel =city.groupby(['arrival_date_month'])['adr'].mean().reset_index()
city_hotel
# Out:
#    arrival_date_month         adr
# 0               April  111.962267
# 1              August  118.674598
# 2            December   88.401855
# 3            February   86.520062
# 4             January   82.330983
# 5                July  115.818019
# 6                June  117.874360
# 7               March   90.658533
# 8                 May  120.669827
# 9            November   86.946592
# 10            October  102.004672
# 11          September  112.776582

# %% [markdown]
# # STEP2: MERGE THE TWO HOTELS

# %%
final=resort_hotel.merge(city_hotel,on='arrival_date_month')
final.columns=['month','price_for_resort','price_for_city_hotel']
final
# Out:
#         month  price_for_resort  price_for_city_hotel
# 0       April         43.726059            111.962267
# 1      August         83.322653            118.674598
# 2    December         37.666300             88.401855
# 3    February         30.845022             86.520062
# 4     January         31.169218             82.330983
# 5        July         70.262366            115.818019
# 6        June         56.346298            117.874360
# 7       March         34.100690             90.658533
# 8         May         42.254335            120.669827
# 9    November         30.002893             86.946592
# 10    October         35.144775            102.004672
# 11  September         50.372746            112.776582

# %%
# !pip install sort_dataframeby_monthorweek
# !pip install sorted_months_weekdays
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
#THIS HELPS TO SORT THE MONTH
import sort_dataframeby_monthorweek as sd
final=sd.Sort_Dataframeby_Month(df=final,monthcolumnname='month')
final
# Out:
#         month  price_for_resort  price_for_city_hotel
# 0     January         31.169218             82.330983
# 1    February         30.845022             86.520062
# 2       March         34.100690             90.658533
# 3       April         43.726059            111.962267
# 4         May         42.254335            120.669827
# 5        June         56.346298            117.874360
# 6        July         70.262366            115.818019
# 7      August         83.322653            118.674598
# 8   September         50.372746            112.776582
# 9     October         35.144775            102.004672
# 10   November         30.002893             86.946592
# 11   December         37.666300             88.401855

# %%
px.line(final, x='month', 
        y=['price_for_resort','price_for_city_hotel'],
        title='Room price per night over the Months')
# Out:
# <div>                            <div id="bc680689-a3e3-4188-afc2-b3f767d5d4b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc680689-a3e3-4188-afc2-b3f767d5d4b5")) {                    Plotly.newPlot(                        "bc680689-a3e3-4188-afc2-b3f767d5d4b5",                        [{"hovertemplate":"variable=price_for_resort\u003cbr\u003emonth=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"price_for_resort","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"price_for_resort","orientation":"v","showlegend":true,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"xaxis":"x","y":[31.16921847088246,30
# ...

# %%
#CALCULATE THE AVERAGE VALUE FOR ADR(AVERAGE DAILY RATE)
data["adr_updated"]=data["adr"]/(data["adults"]+data["children"])
# Out:
# C:\Users\adsa\AppData\Local\Temp\ipykernel_16988\846596181.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
resort = data[(data['hotel'] == 'Resort Hotel') & (data['is_canceled'] ==0)]
city = data[(data['hotel'] == 'City Hotel') & (data['is_canceled'] ==0)]

# %%
resort_hotel=resort.groupby(['arrival_date_month'])['adr_updated'].mean().reset_index()
resort_hotel
# Out:
#    arrival_date_month  adr_updated
# 0               April    43.726059
# 1              August    83.322653
# 2            December    37.666300
# 3            February    30.845022
# 4             January    31.169218
# 5                July    70.262366
# 6                June    56.346298
# 7               March    34.100690
# 8                 May    42.254335
# 9            November    30.002893
# 10            October    35.144775
# 11          September    50.372746

# %%
city_hotel=city.groupby(['arrival_date_month'])['adr_updated'].mean().reset_index()
city_hotel
# Out:
#    arrival_date_month  adr_updated
# 0               April    58.715028
# 1              August    57.771630
# 2            December    47.724939
# 3            February    50.950846
# 4             January    51.280071
# 5                July    57.258853
# 6                June    66.335898
# 7               March    52.477652
# 8                 May    69.987850
# 9            November    57.142431
# 10            October    61.800547
# 11          September    67.042091

# %%
final=resort_hotel.merge(city_hotel,on='arrival_date_month')
final.columns=['month','price_for_resort','price_for_city_hotel']
final
# Out:
#         month  price_for_resort  price_for_city_hotel
# 0       April         43.726059             58.715028
# 1      August         83.322653             57.771630
# 2    December         37.666300             47.724939
# 3    February         30.845022             50.950846
# 4     January         31.169218             51.280071
# 5        July         70.262366             57.258853
# 6        June         56.346298             66.335898
# 7       March         34.100690             52.477652
# 8         May         42.254335             69.987850
# 9    November         30.002893             57.142431
# 10    October         35.144775             61.800547
# 11  September         50.372746             67.042091

# %%
#THIS HELPS TO SORT THE MONTH
import sort_dataframeby_monthorweek as sd
final=sd.Sort_Dataframeby_Month(df=final,monthcolumnname='month')
final
# Out:
#         month  price_for_resort  price_for_city_hotel
# 0     January         31.169218             82.330983
# 1    February         30.845022             86.520062
# 2       March         34.100690             90.658533
# 3       April         43.726059            111.962267
# 4         May         42.254335            120.669827
# 5        June         56.346298            117.874360
# 6        July         70.262366            115.818019
# 7      August         83.322653            118.674598
# 8   September         50.372746            112.776582
# 9     October         35.144775            102.004672
# 10   November         30.002893             86.946592
# 11   December         37.666300             88.401855

# %%
px.line(final, x='month', 
        y=['price_for_resort','price_for_city_hotel'],
        title='Room price per night over the Months')
# Out:
# <div>                            <div id="ff36c267-fb24-4e61-8740-4c40b121650e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff36c267-fb24-4e61-8740-4c40b121650e")) {                    Plotly.newPlot(                        "ff36c267-fb24-4e61-8740-4c40b121650e",                        [{"hovertemplate":"variable=price_for_resort\u003cbr\u003emonth=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"price_for_resort","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"price_for_resort","orientation":"v","showlegend":true,"x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[43.72605862745098,83
# ...

# %% [markdown]
# # ROOM PRICE ANALYSIS: SEEEING HOW PRICES ARE DISTRIBUTED ACROSS THE ROOM TYPE

# %% [markdown]
# # HOW MUCH DO GUEST PAY FOR A ROOM PER NIGHT

# %%
df['reserved_room_type'].unique()
# Out:
# array(['C', 'A', 'D', 'E', 'G', 'F', 'H', 'L', 'P', 'B'], dtype=object)

# %%
#ADD THIS NEW COLUMN
data['adr_updated']=data['adr']/(data['adults']+data['children'])
data
# Out:
# C:\Users\adsa\AppData\Local\Temp\ipykernel_16988\1066531354.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# ...

# %%
#valid_guest = pd.DataFrame(data)
prices = valid_guest[['hotel', 'reserved_room_type', 'adr_updated']].sort_values('reserved_room_type')
prices
# Out:
#               hotel reserved_room_type  adr_updated
# 59636    City Hotel                  A         52.5
# 74210    City Hotel                  A         31.0
# 74209    City Hotel                  A         31.0
# 74208    City Hotel                  A         31.0
# 74207    City Hotel                  A         31.0
# ...             ...                ...          ...
# 15855  Resort Hotel                  L         86.0
# 14381  Resort Hotel                  L          4.0
# 14570  Resort Hotel                  L         82.0
# 354    Resort Hotel                  L         37.5
# 504    Resort Hotel                  L         68.0
#
# [119210 rows x 3 columns]

# %%
data['adr_updated'] = data['adr']/(data['adults']+data['children'])
valid_guest = data.loc[data['is_canceled'] == 0]
price = valid_guest[['hotel', 'reserved_room_type', 'adr_updated']].sort_values('reserved_room_type')

plt.figure(figsize=(12, 8))
sns.boxplot(x='reserved_room_type',
           y='adr_updated',
           hue='hotel',
           data=prices
          )
plt.title('Price of room types per night and person', fontsize=16)
plt.xlabel('Room type', fontsize=16)
plt.ylabel('Price [EUR]', fontsize=16)

plt.ylim(0,160) #this code helps adjust the size
plt.show()
# Out:
# C:\Users\adsa\AppData\Local\Temp\ipykernel_16988\3244122318.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
prices_B=prices[prices['reserved_room_type']== 'B']
prices_B
# Out:
#              hotel reserved_room_type  adr_updated
# 100451  City Hotel                  B       41.915
# 40694   City Hotel                  B       38.250
# 100870  City Hotel                  B       41.460
# 40374   City Hotel                  B       49.100
# 79828   City Hotel                  B       42.500
# ...            ...                ...          ...
# 54314   City Hotel                  B       45.565
# 65270   City Hotel                  B       45.230
# 54472   City Hotel                  B       43.250
# 115624  City Hotel                  B       46.820
# 54475   City Hotel                  B       43.375
#
# [1115 rows x 3 columns]

# %%
prices_City=prices_B[prices_B['hotel']=='City Hotel']
prices_Resort=prices_B[prices_B['hotel']=='Resort Hotel']
prices_Resort
# Out:
#               hotel reserved_room_type  adr_updated
# 35668  Resort Hotel                  B         55.0
# 15796  Resort Hotel                  B         67.0
# 35893  Resort Hotel                  B         35.0

# %%
prices_City
# Out:
#              hotel reserved_room_type  adr_updated
# 100451  City Hotel                  B       41.915
# 40694   City Hotel                  B       38.250
# 100870  City Hotel                  B       41.460
# 40374   City Hotel                  B       49.100
# 79828   City Hotel                  B       42.500
# ...            ...                ...          ...
# 54314   City Hotel                  B       45.565
# 65270   City Hotel                  B       45.230
# 54472   City Hotel                  B       43.250
# 115624  City Hotel                  B       46.820
# 54475   City Hotel                  B       43.375
#
# [1112 rows x 3 columns]

# %%
prices_City.describe()
# Out:
#        adr_updated
# count  1112.000000
# mean     44.054282
# std      18.185049
# min       0.000000
# 25%      37.500000
# 50%      43.250000
# 75%      50.715000
# max     168.500000

# %%
prices_Resort.describe()
# Out:
#        adr_updated
# count     3.000000
# mean     52.333333
# std      16.165808
# min      35.000000
# 25%      45.000000
# 50%      55.000000
# 75%      61.000000
# max      67.000000

# %%
# IQR = 61-45 = 15, WHISRKER = 1.5*15 = 22.5, MAX = 22.5 + 61=83.5, THIS IS WHY THERE ARE NO OUTLIERS
I USED BLOXPLOT TO GET THE OUTLIERS

# %% [markdown]
# # HOW MANY PEOPLE STAY AT THE HOTEL

# %%
df3=data[data['is_canceled']==0]
df3['total_nights'] = df3['stays_in_weekend_nights'] + df3['stays_in_week_nights']
# Out:
# C:\Users\adsa\AppData\Local\Temp\ipykernel_16988\3281167408.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df3
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df4=df3[['total_nights', 'hotel', 'is_canceled']]
df4
# Out:
#         total_nights         hotel  is_canceled
# 0                  0  Resort Hotel            0
# 1                  0  Resort Hotel            0
# 2                  1  Resort Hotel            0
# 3                  1  Resort Hotel            0
# 4                  2  Resort Hotel            0
# ...              ...           ...          ...
# 119385             7    City Hotel            0
# 119386             7    City Hotel            0
# 119387             7    City Hotel            0
# 119388             7    City Hotel            0
# 119389             9    City Hotel            0
#
# [75011 rows x 3 columns]

# %%
hotel_stay=df4.groupby(['total_nights','hotel']).agg('count').reset_index()

# %%
hotel_stay
# Out:
#     total_nights         hotel  is_canceled
# 0              0    City Hotel          251
# 1              0  Resort Hotel          371
# 2              1    City Hotel         9155
# 3              1  Resort Hotel         6579
# 4              2    City Hotel        10983
# ..           ...           ...          ...
# 57            46  Resort Hotel            1
# 58            48    City Hotel            1
# 59            56  Resort Hotel            1
# 60            60  Resort Hotel            1
# 61            69  Resort Hotel            1
#
# [62 rows x 3 columns]

# %%
hotel_stay=hotel_stay.rename(columns={'is_canceled':'Number of stay'})
hotel_stay.head()
# Out:
#    total_nights         hotel  Number of stay
# 0             0    City Hotel             251
# 1             0  Resort Hotel             371
# 2             1    City Hotel            9155
# 3             1  Resort Hotel            6579
# 4             2    City Hotel           10983

# %%
hotel_stay_r=hotel_stay[hotel_stay['hotel']=='Resort Hotel']
hotel_stay_r
# Out:
#     total_nights         hotel  Number of stay
# 1              0  Resort Hotel             371
# 3              1  Resort Hotel            6579
# 5              2  Resort Hotel            4488
# 7              3  Resort Hotel            3828
# 9              4  Resort Hotel            3321
# 11             5  Resort Hotel            1899
# 13             6  Resort Hotel            1205
# 15             7  Resort Hotel            4434
# 17             8  Resort Hotel             509
# 19             9  Resort Hotel             408
# 21            10  Resort Hotel             699
# 23            11  Resort Hotel             240
# 25            12  Resort Hotel              89
# 27            13  Resort Hotel              75
# 29            14  Resort Hotel             630
# 31            15  Resort Hotel              23
# 33            16  Resort Hotel              12
# 35            17  Resort Hotel              11
# 37            18  Resort Hotel               5
# ...

# %%
hotel_stay_c=hotel_stay[hotel_stay['hotel']=='City Hotel']
hotel_stay_c
# Out:
#     total_nights       hotel  Number of stay
# 0              0  City Hotel             251
# 2              1  City Hotel            9155
# 4              2  City Hotel           10983
# 6              3  City Hotel           11889
# 8              4  City Hotel            7694
# 10             5  City Hotel            3210
# 12             6  City Hotel            1111
# 14             7  City Hotel            1245
# 16             8  City Hotel             205
# 18             9  City Hotel             119
# 20            10  City Hotel              80
# 22            11  City Hotel              33
# 24            12  City Hotel              33
# 26            13  City Hotel              15
# 28            14  City Hotel              26
# 30            15  City Hotel              14
# 32            16  City Hotel               6
# 34            17  City Hotel               4
# 36            18  City Hotel               1
# 38            19  City Hotel               2
# ...

# %%
trace= go.Bar(
    x=hotel_stay_r["total_nights"],
    y=hotel_stay_r["Number of stay"],
    name='Resort Stay'
)

trace1= go.Bar(
    x=hotel_stay_c["total_nights"],
    y=hotel_stay_c["Number of stay"],
    name='City Stay'
)

data5 = [trace, trace1]
layout = go.Layout(
    title="Total Number of stays by Guest"
)
fig = go.Figure(data=data5, layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %% [markdown]
# ''' ### Combined Observational Conclusion
#
# 1. Stay Duration Patterns:
#
# City Hotel:
#     Short Stays: Dominates with the highest number of stays for 1 night (9155 stays). Numbers drop sharply for longer stays, indicating a preference for brief visits.
#
# Resort Hotel:
#     Short Stays: Also high, but less pronounced than the City Hotel.
#     Long Stays: Notable numbers for durations up to 30 nights, showing that guests often stay longer at resorts compared to city hotels.
#
# 2. Distribution Insights:
#
# City Hotel: Strong focus on short stays. Ideal for transient guests.
# Resort Hotel: Broader range of stay durations, indicating appeal to both short-term and long-term guests.
#
# 3. Practical Implications:
#
# City Hotel: Optimize for short stays and manage frequent turnovers.
# Resort Hotel: Promote long stays and vacation packages to attract guests for extended periods.'''

# %% [markdown]
# # BOOKING BY MARKET SEGMEN

# %%
segments=data['market_segment'].value_counts()
segments
# Out:
# market_segment
# Online TA        56408
# Offline TA/TO    24182
# Groups           19791
# Direct           12582
# Corporate         5282
# Complementary      728
# Aviation           235
# Undefined            2
# Name: count, dtype: int64

# %%
#pie plot

fig = px.pie(segments,
            values=segments.values,
            names=segments.index,
            title="Bookings per market segment",
            template="seaborn")
fig.update_traces(rotation=-90, textinfo="percent+label")
fig.show()
# Out:
# <div>                            <div id="15d1ee69-f3af-4918-b9ae-0a331ad8b877" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15d1ee69-f3af-4918-b9ae-0a331ad8b877")) {                    Plotly.newPlot(                        "15d1ee69-f3af-4918-b9ae-0a331ad8b877",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"market_segment=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Online TA","Offline TA\u002fTO","Groups","Direct","Corporate","Complementary","Aviation","Undefined"],"legendgroup":"","name":"","showlegend":true,"values":[56408,24182,19791,12582,5282,728,235,2],"type":"pie","rotation":-90,"textinfo":"percent+label"}],                        {"template":{"data":{"barpol
# ...

# %%
plt.figure(figsize=(12,8))
sns.barplot(x="market_segment",
            y="adr_updated",
            hue="reserved_room_type",
            data=data,
            ci=None)
plt.title("ADR by market segment and room type", fontsize=16)
plt.xlabel("Market segment", fontsize=16)
plt.xticks(rotation=45)
plt.ylabel("ADR per person [EUR]", fontsize=16)
plt.legend(loc="upper left")
plt.show()
# Out:
# C:\Users\adsa\AppData\Local\Temp\ipykernel_16988\2603043914.py:2: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.

# %% [markdown]
# This code creates a bar plot that compares the ADR per person across different market segments, with bars color-coded by room type. The plot helps visualize how ADR varies by market segment and room type, providing insights into pricing trends and room preferences.

# %% [markdown]
# # HOW MANY BOOKINGS WERE CANCELED?

# %%
Canceled=data['is_canceled']==1

# %%
cancel =Canceled.sum()

# %%
resort_cancelation = data.loc[data['hotel'] == 'Resort Hotel']['is_canceled'].sum()
city_cancelation = data.loc[data['hotel'] == 'City Hotel']['is_canceled'].sum()

# %%
resort_cancelation
# Out:
# 11120

# %%
city_cancelation
# Out:
# 33079

# %%
print(f"Total Booking Cancelled: {cancel}. ")
print(f"Total Resort Hotel Booking Cancelled: {resort_cancelation}. ")
print(f"Total City Hotel Booking Cancelled: {city_cancelation}. ")
# Out:
# Total Booking Cancelled: 44199.
# Total Resort Hotel Booking Cancelled: 11120.
# Total City Hotel Booking Cancelled: 33079.

# %% [markdown]
# # WHICH MONTH WITH THE HIGHEST NUMBER OF CANCELATIONS?

# %%
res_book_per_month = data.loc[(data['hotel'] == 'Resort Hotel')].groupby("arrival_date_month")["hotel"].count()
res_cancel_per_month = data.loc[(data['hotel'] == 'Resort Hotel')].groupby("arrival_date_month")["is_canceled"].sum()

cty_book_per_month = data.loc[(data['hotel'] == 'City Hotel')].groupby("arrival_date_month")["hotel"].count()
cty_cancel_per_month = data.loc[(data['hotel'] == 'City Hotel')].groupby("arrival_date_month")["is_canceled"].sum()

res_cancel_data = pd.DataFrame({'Hotel': 'Resort Hotel',
                                'Month': list(res_book_per_month.index),
                                'Bookings': list(res_book_per_month.values),
                                'Cancelations':list(res_cancel_per_month.values)})
cty_cancel_data = pd.DataFrame({'Hotel': 'City Hotel',
                                'Month': list(cty_book_per_month.index),
                                'Bookings': list(cty_book_per_month.values),
                                'Cancelations':list(cty_cancel_per_month.values)})
full_cancel_data = pd.concat([res_cancel_data, cty_cancel_data], ignore_index=True)

# %%
res_book_per_month
# Out:
# arrival_date_month
# April        3609
# August       4894
# December     2645
# February     3102
# January      2191
# July         4573
# June         3044
# March        3334
# May          3559
# November     2435
# October      3553
# September    3108
# Name: hotel, dtype: int64

# %%
res_cancel_per_month
# Out:
# arrival_date_month
# April        1059
# August       1637
# December      631
# February      794
# January       325
# July         1436
# June         1007
# March         763
# May          1024
# November      460
# October       978
# September    1006
# Name: is_canceled, dtype: int64

# %%
res_cancel_data
# Out:
#            Hotel      Month  Bookings  Cancelations
# 0   Resort Hotel      April      3609          1059
# 1   Resort Hotel     August      4894          1637
# 2   Resort Hotel   December      2645           631
# 3   Resort Hotel   February      3102           794
# 4   Resort Hotel    January      2191           325
# 5   Resort Hotel       July      4573          1436
# 6   Resort Hotel       June      3044          1007
# 7   Resort Hotel      March      3334           763
# 8   Resort Hotel        May      3559          1024
# 9   Resort Hotel   November      2435           460
# 10  Resort Hotel    October      3553           978
# 11  Resort Hotel  September      3108          1006

# %%
full_cancel_data
# Out:
#            Hotel      Month  Bookings  Cancelations
# 0   Resort Hotel      April      3609          1059
# 1   Resort Hotel     August      4894          1637
# 2   Resort Hotel   December      2645           631
# 3   Resort Hotel   February      3102           794
# 4   Resort Hotel    January      2191           325
# 5   Resort Hotel       July      4573          1436
# 6   Resort Hotel       June      3044          1007
# 7   Resort Hotel      March      3334           763
# 8   Resort Hotel        May      3559          1024
# 9   Resort Hotel   November      2435           460
# 10  Resort Hotel    October      3553           978
# 11  Resort Hotel  September      3108          1006
# 12    City Hotel      April      7469          3459
# 13    City Hotel     August      8967          3600
# 14    City Hotel   December      4114          1737
# 15    City Hotel   February      4950          1899
# 16    City Hotel    January      3730          1481
# ...

# %%
import sort_dataframeby_monthorweek as sd
res_cancel_data=sd.Sort_Dataframeby_Month(df=res_cancel_data,monthcolumnname='Month')
res_cancel_data
# Out:
#            Hotel      Month  Bookings  Cancelations
# 0   Resort Hotel    January      2191           325
# 1   Resort Hotel   February      3102           794
# 2   Resort Hotel      March      3334           763
# 3   Resort Hotel      April      3609          1059
# 4   Resort Hotel        May      3559          1024
# 5   Resort Hotel       June      3044          1007
# 6   Resort Hotel       July      4573          1436
# 7   Resort Hotel     August      4894          1637
# 8   Resort Hotel  September      3108          1006
# 9   Resort Hotel    October      3553           978
# 10  Resort Hotel   November      2435           460
# 11  Resort Hotel   December      2645           631

# %%
import sort_dataframeby_monthorweek as sd
cty_cancel_data=sd.Sort_Dataframeby_Month(df=cty_cancel_data,monthcolumnname='Month')
cty_cancel_data
# Out:
#          Hotel      Month  Bookings  Cancelations
# 0   City Hotel    January      3730          1481
# 1   City Hotel   February      4950          1899
# 2   City Hotel      March      6434          2385
# 3   City Hotel      April      7469          3459
# 4   City Hotel        May      8221          3653
# 5   City Hotel       June      7885          3527
# 6   City Hotel       July      8071          3301
# 7   City Hotel     August      8967          3600
# 8   City Hotel  September      7392          3109
# 9   City Hotel    October      7594          3268
# 10  City Hotel   November      4336          1660
# 11  City Hotel   December      4114          1737

# %%
plt.figure(figure=(12,8))

trace= go.Bar(
    x=res_cancel_data["Month"],
    y=res_cancel_data["Cancelations"],
    name='Rst Cancelled'
)

trace1= go.Bar(
    x=cty_cancel_data["Month"],
    y=cty_cancel_data["Cancelations"],
    name='Cty Cancelled'

)

data6 = [trace,trace1]
layout = go.Layout(
    title='Total Number of stays by Guest'
)
fig = go.Figure(data=data6, layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'
